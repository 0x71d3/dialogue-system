# %% [markdown]
# <a href="https://colab.research.google.com/github/0x71d3/simple-dialogue-system/blob/master/SimpleDialogueSystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simple Dialogue System

# %% [markdown]
# https://github.com/0x71d3/simple-dialogue-system

# %% [markdown]
# ## Install

# %%
# !apt install libsox-dev
# !git clone http://github.com/pytorch/audio
# !cd audio;python setup.py install
# !git clone https://github.com/OpenNMT/OpenNMT-py
# !pip install -r OpenNMT-py/requirements.opt.txt
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libao-common libao4 libid3tag0 libmad0 libmagic-mgc libmagic1
#   libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-all libsox-fmt-alsa
#   libsox-fmt-ao libsox-fmt-base libsox-fmt-mp3 libsox-fmt-oss libsox-fmt-pulse
#   libsox3
# Suggested packages:
#   libaudio2 file
# The following NEW packages will be installed:
#   libao-common libao4 libid3tag0 libmad0 libmagic-mgc libmagic1
#   libopencore-amrnb0 libopencore-amrwb0 libsox-dev libsox-fmt-all
#   libsox-fmt-alsa libsox-fmt-ao libsox-fmt-base libsox-fmt-mp3 libsox-fmt-oss
#   libsox-fmt-pulse libsox3
# 0 upgraded, 17 newly installed, 0 to remove and 29 not upgraded.
# Need to get 1,166 kB of archives.
# After this operation, 8,955 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopencore-amrnb0 amd64 0.1.3-2.1 [92.0 kB]
# ...

# %% [markdown]
# ## Preprocess

# %%
# !pip install configargparse
# !pip install torchtext==0.4.0
# !python OpenNMT-py/preprocess.py -train_src drive/My\ Drive/simple-dialogue-system/data/src-train.txt -train_tgt drive/My\ Drive/simple-dialogue-system/data/tgt-train.txt -valid_src drive/My\ Drive/simple-dialogue-system/data/src-val.txt -valid_tgt drive/My\ Drive/simple-dialogue-system/data/tgt-val.txt -save_data drive/My\ Drive/simple-dialogue-system/data/demo
# Out:
# ...
#      |████████████████████████████████| 51kB 4.4MB/s
# ...
#   Created wheel for configargparse: filename=ConfigArgParse-1.2.3-cp36-none-any.whl size=19328 sha256=9b3805eeb837614e85f5cac612079c68dd4b01f3cf6f7e29f98f2c3e97d666e2
#   Stored in directory: /root/.cache/pip/wheels/bd/d6/53/034032da9498bda2385cd50a51a289e88090b5da2d592b1fdf
# Successfully built configargparse
# ...
#      |████████████████████████████████| 61kB 5.0MB/s
# ...
#   Found existing installation: torchtext 0.3.1
#     Uninstalling torchtext-0.3.1:
#       Successfully uninstalled torchtext-0.3.1
# ...
# [2020-05-10 07:01:32,750 INFO] Extracting features...
# [2020-05-10 07:01:36,621 INFO]  * number of source features: 0.
# [2020-05-10 07:01:36,621 INFO]  * number of target features: 0.
# [2020-05-10 07:01:36,621 INFO] Building `Fields` object...
# [2020-05-10 07:01:36,621 INFO] Building & saving training data...
# ...

# %% [markdown]
# ## Train

# %%
# !python OpenNMT-py/train.py -data drive/My\ Drive/simple-dialogue-system/data/demo -save_model drive/My\ Drive/simple-dialogue-system/data/model/demo-model -layers 6 -rnn_size 512 -word_vec_size 512 -transformer_ff 2048 -heads 8 -encoder_type transformer -decoder_type transformer -position_encoding -train_steps 20000 -max_generator_batches 2 -dropout 0.1 -batch_size 4096 -batch_type tokens -normalization tokens -accum_count 2 -optim adam -adam_beta2 0.998 -decay_method noam -warmup_steps 8000 -learning_rate 2 -max_grad_norm 0 -param_init 0 -param_init_glorot -label_smoothing 0.1 -valid_steps 1000 -save_checkpoint_steps 5000 -world_size 1 -gpu_rank 0
# Out:
# [2020-05-10 07:01:41,885 INFO]  * src vocab size = 50002
# [2020-05-10 07:01:41,885 INFO]  * tgt vocab size = 50004
# [2020-05-10 07:01:41,885 INFO] Building model...
# [2020-05-10 07:01:53,244 INFO] NMTModel(
#   (encoder): TransformerEncoder(
#     (embeddings): Embeddings(
#       (make_embedding): Sequential(
#         (emb_luts): Elementwise(
#           (0): Embedding(50002, 512, padding_idx=1)
#         )
#         (pe): PositionalEncoding(
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (transformer): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiHeadedAttention(
#           (linear_keys): Linear(in_features=512, out_features=512, bias=True)
#           (linear_values): Linear(in_features=512, out_features=512, bias=True)
#           (linear_query): Linear(in_features=512, out_features=512, bias=True)
#           (softmax): Softmax(dim=-1)
#           (dropout): Dropout(p=0.1, inplace=False)
# ...

# %% [markdown]
# ## Translate

# %%
# !python OpenNMT-py/translate.py -model drive/My\ Drive/simple-dialogue-system/data/model/demo-model_step_20000.pt -src drive/My\ Drive/simple-dialogue-system/data/src-test.txt -output drive/My\ Drive/simple-dialogue-system/data/pred.txt -replace_unk -verbose
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# PRED 1751: 地元 の 人 は 行か ない の ？
# PRED SCORE: -6.6213
#
# SENT 1752: ['真面目に', '空腹', '感', 'ヤバ', 'すぎて', 'しに', 'そう', 'カップ', '麺', '食う', 'か', '…']
# PRED 1752: クソ ワロタ www
# PRED SCORE: -2.6832
#
# SENT 1753: ['AC', '版', '？', 'って', '話', 'を', 'ちらほら', '耳', 'に', 'する', '割に', '全く', 'ソース', 'が', '出て', 'こ', 'ない', 'んだ', 'けど', 'esuteru', '以外', 'で', '何', 'か', 'ある', 'ん', 'す', 'か']
# PRED 1753: 耐え られ そうに ない んです よ ね 。
# PRED SCORE: -5.3652
#
# SENT 1754: ['J', 'スト', '内', 'に', 'エイト', 'の', 'レーベル', 'てこ', 'と', '？', 'テイチク', 'から', 'スタッフ', '引っ張れる', '？', 'テイチク', 'に', '申し訳ない', 'か', '…', 'スバラジ', 'と', 'か', 'どー', 'なる', 'ん', '？', 'エイト', '大丈夫', '？', 'ヨコ', '泣いて', 'た', 'の', 'も', 'ヒナ', 'や', 'すばる', 'の', '言葉', 'も', '今', '思う', 'と', '…']
# PRED 1754: 会って 教えて 下さい ！ 笑
# PRED SCORE: -3.4945
#
# SENT 1755: ['こんなに', '相葉', 'さん', 'を', '近く', 'に', '感じた', 'の', 'はじめて', '。', 'すき', '。']
# PRED 1755: 違う 笑笑
# PRED SCORE: -3.3382
#
# ...
